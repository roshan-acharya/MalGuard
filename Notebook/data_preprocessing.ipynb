# %%
import pandas as pd 
import numpy as np
from urllib.parse import * 
import whois
from datetime import datetime

# %%
df=pd.read_csv('..\Data\safe_link.csv',header=None,names=['url']) 
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Roshan Acharya\AppData\Local\Temp\ipykernel_13280\603640640.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv('..\Data\safe_link.csv',header=None,names=['url'])
#                             url
# 0          https://facebook.com
# 1  https://fonts.googleapis.com
# 2           https://youtube.com
# 3            https://google.com
# 4  https://googletagmanager.com

# %%
suspicious_words = ['login', 'signin', 'verify', 'update', 'banking', 'account', 'secure', 'ebayisapi', 'webscr', 'paypal','esewa','account']

        
for url in df['url']:
    parse_url = urlparse(url)
    domain = parse_url.netloc
    scheme= parse_url.scheme
    path = parse_url.path

    #Suspicious check
    df['suspicious'] = df['url'].apply(lambda x: any(word in x for word in suspicious_words))
    
    #Length check of domain
    df['length_domain'] = df['url'].apply(lambda x: len(urlparse(x).netloc))
    df['count_dots']=df['url'].apply(lambda x: x.count('.'))
    df['count_dashes']=df['url'].apply(lambda x: x.count('-'))
    df['https']=df['url'].apply(lambda x: 1 if 'https' in scheme else 0)
    df['count_at_symbol']=df['url'].apply(lambda x: x.count('@'))
    df['count_digits']=df['url'].apply(lambda x: sum(c.isdigit() for c in x))

    df['Label']='Safe'

  


df.head(5)
# Out:
#                             url  suspicious  length_domain  count_dots  \
# 0          https://facebook.com       False             12           1
# 1  https://fonts.googleapis.com       False             20           2
# 2           https://youtube.com       False             11           1
# 3            https://google.com       False             10           1
# 4  https://googletagmanager.com       False             20           1
#
#    count_dashes  https  count_at_symbol  count_digits Label  Domain age
# 0             0      1                0             0  Safe          -1
# 1             0      1                0             0  Safe          -1
# 2             0      1                0             0  Safe          -1
# 3             0      1                0             0  Safe          -1
# 4             0      1                0             0  Safe          -1

# %%
# Out:
# -1
